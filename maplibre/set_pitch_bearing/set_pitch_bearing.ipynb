# %% [markdown]
# [![image](https://jupyterlite.rtfd.io/en/latest/_static/badge.svg)](https://demo.leafmap.org/lab/index.html?path=maplibre/set_pitch_bearning.ipynb)
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/leafmap/blob/master/docs/maplibre/set_pitch_bearning.ipynb)
# [![image](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/opengeos/leafmap/HEAD)
#
# **Set pitch and bearing**
#
# This source code of this example is adapted from the MapLibre GL JS example - [Set pitch and bearing](https://maplibre.org/maplibre-gl-js/docs/examples/set-perspective/).
#
# Uncomment the following line to install [leafmap](https://leafmap.org) if needed.

# %%
# %pip install "leafmap[maplibre]"

# %%
import leafmap.maplibregl as leafmap

# %% [markdown]
# To run this notebook, you will need an [API key](https://docs.maptiler.com/cloud/api/authentication-key/) from [MapTiler](https://www.maptiler.com/cloud/). Once you have the API key, you can uncomment the following code block and replace `YOUR_API_KEY` with your actual API key. Then, run the code block code to set the API key as an environment variable.

# %%
# import os
# os.environ["MAPTILER_KEY"] = "YOUR_API_KEY"

# %%
m = leafmap.Map(
    center=[-73.5804, 45.53483], zoom=10, pitch=60, bearing=-60, style="streets"
)
m

# %% [markdown]
# ![](https://i.imgur.com/onKRYXz.png)
