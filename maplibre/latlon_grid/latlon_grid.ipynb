# %% [markdown]
# [![image](https://jupyterlite.rtfd.io/en/latest/_static/badge.svg)](https://demo.leafmap.org/lab/index.html?path=maplibre/latlon_grid.ipynb)
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/leafmap/blob/master/docs/maplibre/latlon_grid.ipynb)
# [![image](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/opengeos/leafmap/HEAD)
#
# **Generate a lat-lon grid**
#
# Uncomment the following line to install [leafmap](https://leafmap.org) if needed.

# %%
# %pip install leafmap

# %%
import leafmap.maplibregl as leafmap

# %%
extent = (-125, 24, -66, 50)
grid = leafmap.generate_latlon_grid(extent, dx=1, dy=1)
print(len(grid), "grid cells")
grid.head()

# %%
m = leafmap.Map(center=[-100, 40], zoom=3, style="liberty")
m.add_gdf(
    grid,
    name="Grid",
    layer_type="fill",
    paint={
        "fill-color": "rgba(0, 0, 0, 0)",
        "fill-outline-color": "rgba(255, 0, 0, 255)",
    },
    fit_bounds=False,
)
m

# %% [markdown]
# ![](https://github.com/user-attachments/assets/acb5c800-8b1e-4af0-beda-a7eb2f4e2b7c)
